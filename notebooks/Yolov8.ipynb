# %%
# !pip install ultralytics -q

# %%
import yaml, os

yaml_path = r"D:/University/Semester 7/Research/final-year-research/dataset/citipersons/data.yaml"

data = {
    "path": r"D:/University/Semester 7/Research/final-year-research/dataset/citipersons",
    "train": "train/images",
    "val": "valid/images",
    "test": "test/images",
    "names": {0: "ped"}
}

with open(yaml_path, "w") as f:
    yaml.dump(data, f, sort_keys=False)

print("Saved:", yaml_path)
print(open(yaml_path, "r").read())
# Out:
# Saved: D:/University/Semester 7/Research/final-year-research/dataset/citipersons/data.yaml
# path: D:/University/Semester 7/Research/final-year-research/dataset/citipersons
# train: train/images
# val: valid/images
# test: test/images
# names:
#   0: ped

# %%
# !yolo detect train model=yolov8n.pt data="D:/University/Semester 7/Research/final-year-research/dataset/citipersons/data.yaml" epochs=50 imgsz=640 batch=4 device=cpu workers=0
# Out:
# ^C
